# %%
import neurom.viewer

# %%
neurom.viewer.draw(neurom.load_neuron('morphologies/HL23PV.swc'))
neurom.viewer.draw(neurom.load_neuron('morphologies/HL23PV.swc') , mode='3d')
neurom.viewer.draw(neurom.load_neuron('morphologies/HL23PV.swc') , mode='dendrogram')
# Out:
# /var/folders/1d/yzj899_9707g4bqm51x7v20w0000gn/T/ipykernel_82327/2210399972.py:1: NeuroMDeprecationWarning: `neurom.io.utils.load_neuron` is deprecated in favor of `neurom.io.utils.load_morphology`
#   neurom.viewer.draw(neurom.load_neuron('morphologies/HL23PV.swc'))
# /var/folders/1d/yzj899_9707g4bqm51x7v20w0000gn/T/ipykernel_82327/2210399972.py:2: NeuroMDeprecationWarning: `neurom.io.utils.load_neuron` is deprecated in favor of `neurom.io.utils.load_morphology`
#   neurom.viewer.draw(neurom.load_neuron('morphologies/HL23PV.swc') , mode='3d')
# /var/folders/1d/yzj899_9707g4bqm51x7v20w0000gn/T/ipykernel_82327/2210399972.py:3: NeuroMDeprecationWarning: `neurom.io.utils.load_neuron` is deprecated in favor of `neurom.io.utils.load_morphology`
#   neurom.viewer.draw(neurom.load_neuron('morphologies/HL23PV.swc') , mode='dendrogram')
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:title={'center':'Morphology Dendrogram'}, xlabel='micrometers (um)', ylabel='micrometers (um)'>)

# %%
neurom.viewer.draw(neurom.load_neuron('morphologies/HL23PYR.swc'))
neurom.viewer.draw(neurom.load_neuron('morphologies/HL23PYR.swc') , mode='3d')
neurom.viewer.draw(neurom.load_neuron('morphologies/HL23PYR.swc') , mode='dendrogram')
# Out:
# /var/folders/1d/yzj899_9707g4bqm51x7v20w0000gn/T/ipykernel_82327/160926429.py:1: NeuroMDeprecationWarning: `neurom.io.utils.load_neuron` is deprecated in favor of `neurom.io.utils.load_morphology`
#   neurom.viewer.draw(neurom.load_neuron('morphologies/HL23PYR.swc'))
# /var/folders/1d/yzj899_9707g4bqm51x7v20w0000gn/T/ipykernel_82327/160926429.py:2: NeuroMDeprecationWarning: `neurom.io.utils.load_neuron` is deprecated in favor of `neurom.io.utils.load_morphology`
#   neurom.viewer.draw(neurom.load_neuron('morphologies/HL23PYR.swc') , mode='3d')
# /var/folders/1d/yzj899_9707g4bqm51x7v20w0000gn/T/ipykernel_82327/160926429.py:3: NeuroMDeprecationWarning: `neurom.io.utils.load_neuron` is deprecated in favor of `neurom.io.utils.load_morphology`
#   neurom.viewer.draw(neurom.load_neuron('morphologies/HL23PYR.swc') , mode='dendrogram')
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:title={'center':'Morphology Dendrogram'}, xlabel='micrometers (um)', ylabel='micrometers (um)'>)

# %%
neurom.viewer.draw(neurom.load_neuron('morphologies/HL23SST.swc'))
neurom.viewer.draw(neurom.load_neuron('morphologies/HL23SST.swc') , mode='3d')
neurom.viewer.draw(neurom.load_neuron('morphologies/HL23SST.swc') , mode='dendrogram')
# Out:
# /var/folders/1d/yzj899_9707g4bqm51x7v20w0000gn/T/ipykernel_82327/2867080568.py:1: NeuroMDeprecationWarning: `neurom.io.utils.load_neuron` is deprecated in favor of `neurom.io.utils.load_morphology`
#   neurom.viewer.draw(neurom.load_neuron('morphologies/HL23SST.swc'))
# /var/folders/1d/yzj899_9707g4bqm51x7v20w0000gn/T/ipykernel_82327/2867080568.py:2: NeuroMDeprecationWarning: `neurom.io.utils.load_neuron` is deprecated in favor of `neurom.io.utils.load_morphology`
#   neurom.viewer.draw(neurom.load_neuron('morphologies/HL23SST.swc') , mode='3d')
# /var/folders/1d/yzj899_9707g4bqm51x7v20w0000gn/T/ipykernel_82327/2867080568.py:3: NeuroMDeprecationWarning: `neurom.io.utils.load_neuron` is deprecated in favor of `neurom.io.utils.load_morphology`
#   neurom.viewer.draw(neurom.load_neuron('morphologies/HL23SST.swc') , mode='dendrogram')
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:title={'center':'Morphology Dendrogram'}, xlabel='micrometers (um)', ylabel='micrometers (um)'>)

# %%
neurom.viewer.draw(neurom.load_neuron('morphologies/HL23VIP.swc'))
neurom.viewer.draw(neurom.load_neuron('morphologies/HL23VIP.swc') , mode='3d')
neurom.viewer.draw(neurom.load_neuron('morphologies/HL23VIP.swc') , mode='dendrogram')
# Out:
# /var/folders/1d/yzj899_9707g4bqm51x7v20w0000gn/T/ipykernel_82327/1326211833.py:1: NeuroMDeprecationWarning: `neurom.io.utils.load_neuron` is deprecated in favor of `neurom.io.utils.load_morphology`
#   neurom.viewer.draw(neurom.load_neuron('morphologies/HL23VIP.swc'))
#
# morphologies/HL23VIP.swc:6014:warning
# ...
# Neurites are not supposed to have parentId: -1
# (although this is normal if this neuron has no soma)
#
# morphologies/HL23VIP.swc:6032:warning
# ...
# Neurites are not supposed to have parentId: -1
# (although this is normal if this neuron has no soma)
#
# morphologies/HL23VIP.swc:6136:warning
# ...
# Neurites are not supposed to have parentId: -1
# (although this is normal if this neuron has no soma)
#
# morphologies/HL23VIP.swc:6147:warning
# ...
# Neurites are not supposed to have parentId: -1
# (although this is normal if this neuron has no soma)
#
# morphologies/HL23VIP.swc:6468:warning
# ...
# Neurites are not supposed to have parentId: -1
# ...
